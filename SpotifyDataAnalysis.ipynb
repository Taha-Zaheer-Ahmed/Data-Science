# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Hp\\Desktop\\Python\\DataScience\\spotify-2023.csv', encoding='latin-1')

# %%
df.loc[df['in_spotify_charts'] == 1].sort_values(by = 'released_year')
# Out:
#                                             track_name  \
# 871                                Sweet Child O' Mine
# 672                                            HUMBLE.
# 695                                          Adore You
# 756                                             Golden
# 822                                          San Lucas
# 927                I Really Want to Stay at Your House
# 536                                        Malvadï¿½ï¿
# 583                                             ELEVEN
# 667  Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Ab...
# 732                                      X ï¿½ï¿½LTIMA
# 786                                   Un Verano Sin Ti
# 828                       Music For a Sushi Restaurant
# 846                                       Keep Driving
# 851                                        Daydreaming
# 228           Hummingbird (Metro Boomin & James Blake)
# 254                                       Mejor Que Yo
#
# ...

# %%
df.shape
# Out:
# (953, 24)

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df[(df['key'] == 'F#') & (df['mode'] == 'Minor') & (df['released_year'] > 2020)].sort_values(by = ['streams'], ascending = False)
# Out:
#                                       track_name  \
# 427                            Where Are You Now
# 336                            Ainï¿½ï¿½ï¿½t Tha
# 258     Conexï¿½ï¿½es de Mï¿½ï¿½fia (feat. Rich
# 607                                         2055
# 27                                  MOJABI GHOST
# 223  Snow On The Beach (feat. More Lana Del Rey)
# 78                                    Yandel 150
# 304                              SORRY NOT SORRY
# 632                                     AM Remix
# 10                                     un x100to
# 335                                     Miss You
# 252                             The Color Violet
# 255                                     Curtains
# 198                                        Ditto
# 376                               Maan Meri Jaan
# 784                                     Aguacero
# 645                     Esqueï¿½ï¿½a-Me Se For C
# 14                                     As It Was
# ...

# %%
df.loc[df['acousticness_%'] >= 90]
# Out:
#                                             track_name  \
# 17   What Was I Made For? [From The Motion Picture ...
# 128                               lovely - Bonus Track
# 167                                   The Night We Met
# 169                                When I Was Your Man
# 349                                    Kahani Suno 2.0
# 387  Lift Me Up - From Black Panther: Wakanda Forev...
# 416                                              Blind
# 445        It's Beginning To Look A Lot Like Christmas
# 448             Let It Snow! Let It Snow! Let It Snow!
# 469                                    White Christmas
# 575                          LA FAMA (with The Weeknd)
# 587                                      Miserable Man
# 608                                              Bored
# 623                                          All of Me
# 652       The Joker And The Queen (feat. Taylor Swift)
# 691                                            Forever
# ...

# %%
df[(df['artist(s)_name'] == 'The Weeknd, ROSALï¿½')]
# Out:
#                     track_name        artist(s)_name  artist_count  \
# 575  LA FAMA (with The Weeknd)  The Weeknd, ROSALï¿½             2
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 575           2021              11            11                  4640
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm  key   mode  \
# 575                  3  374706940                  81  ...  136  NaN  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 575             77         82       30             95                   0
#
#      liveness_%  speechiness_%
# 575          13              5
#
# [1 rows x 24 columns]

# %%
df['artist(s)_name'].value_counts()
# Out:
# artist(s)_name
# Taylor Swift                 34
# The Weeknd                   22
# Bad Bunny                    19
# SZA                          19
# Harry Styles                 17
#                              ..
# Karol G, Ovy On The Drums     1
# Coolio, L.V.                  1
# Kordhell                      1
# Kenia OS                      1
# Feid, Sech, Jhayco            1
# Name: count, Length: 645, dtype: int64

# %%
df['artist(s)_name'].value_counts().sort_values(ascending = False)
# Out:
# artist(s)_name
# Taylor Swift                                          34
# The Weeknd                                            22
# Bad Bunny                                             19
# SZA                                                   19
# Harry Styles                                          17
#                                                       ..
# Pharrell Williams, Tyler, The Creator, 21 Savage       1
# Sidhu Moose Wala                                       1
# Calvin Harris, Dua Lipa, Young Thug                    1
# Nengo Flow, Anuel Aa, Chris Jedi, Chencho Corleone     1
# Feid, Sech, Jhayco                                     1
# Name: count, Length: 645, dtype: int64

# %%
df['artist(s)_name'].max()
# Out:
# 'teto'

# %%
df.max(numeric_only = True)
# Out:
# artist_count                8
# released_year            2023
# released_month             12
# released_day               31
# in_spotify_playlists    52898
# in_spotify_charts         147
# in_apple_playlists        672
# in_apple_charts           275
# in_deezer_charts           58
# bpm                       206
# danceability_%             96
# valence_%                  97
# energy_%                   97
# acousticness_%             97
# instrumentalness_%         91
# liveness_%                 97
# speechiness_%              64
# dtype: int64

# %%
df.loc[df['artist_count'] == df['artist_count'].max(), ['artist(s)_name', 'energy_%']]
# Out:
#                                         artist(s)_name  energy_%
# 35   Big One, Duki, Lit Killah, Maria Becerra, FMK,...        68
# 642  Arcangel, De La Ghetto, Justin Quiles, Lenny T...        76

# %%
df[['artist(s)_name', 'energy_%']][df['artist_count'] == df['artist_count'].max()]
# Out:
#                                         artist(s)_name  energy_%
# 35   Big One, Duki, Lit Killah, Maria Becerra, FMK,...        68
# 642  Arcangel, De La Ghetto, Justin Quiles, Lenny T...        76
